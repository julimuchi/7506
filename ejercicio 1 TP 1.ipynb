# %%
import pandas as pd
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
df = pd.read_csv('/content/drive/MyDrive/Organizacion de Datos (7506)/TP1/Wikipedia dataset 2c2021/categorylinks.csv')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 13308619 entries, 0 to 13308618
# Data columns (total 7 columns):
#  #   Column             Dtype
# ---  ------             -----
#  0   cl_from            int64
#  1   cl_to              object
#  2   cl_sortkey         object
#  3   cl_timestamp       object
#  4   cl_sortkey_prefix  object
#  5   cl_collation       object
#  6   cl_type            object
# dtypes: int64(1), object(6)
# memory usage: 710.8+ MB

# %% [markdown]
# Me quedo unicamente con las columnas, que segun el enunciado, conocemos su significado.

# %%
df_original = df
df = df[["cl_to", "cl_timestamp", "cl_type"]]

# %% [markdown]
# renombro las columas

# %%
df.columns = ["categoria", "fecha_asignacion", "contenido"]
# Out:
# Index(['categoria', 'fecha_asignacion', 'contenido'], dtype='object')

# %% [markdown]
# elimno la columna "categoria" (la podria haber elimnado previamente, pero por prolijidad la saco ahora)

# %%
df = df[["fecha_asignacion", "contenido"]]

# %% [markdown]
# Ordeno por fecha de de asignacion ascendente

# %%
df.sort_values(["fecha_asignacion"])
# Out:
#              fecha_asignacion contenido
# 12528     2004-08-14 05:00:33      page
# 31633     2004-08-14 05:38:32      page
# 64005     2004-08-14 06:48:06      page
# 67867     2004-08-14 06:52:59      page
# 72135     2004-08-14 07:00:10      page
# ...                       ...       ...
# 10208419  2021-09-01 17:05:18    subcat
# 13308618  2021-09-01 17:05:42    subcat
# 13308617  2021-09-01 17:05:42    subcat
# 8966871   2021-09-01 17:06:31      page
# 11788956  2021-09-01 17:06:32      page
#
# [13308619 rows x 2 columns]

# %% [markdown]
# Por lo tanto el contenido que se le asigno por primera vez una categoria es "page"
